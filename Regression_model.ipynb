# %%
# importing required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
#from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
import warnings
warnings.filterwarnings('ignore')

# %%
# Reading the file and checking it
df = pd.read_csv('AIDS_Classification_50000.csv')
df.head(5)
# Out:
#    time  trt  age       wtkg  hemo  homo  drugs  karnof  oprior  z30  ...  \
# 0  1073    1   37   79.46339     0     1      0     100       0    1  ...
# 1   324    0   33   73.02314     0     1      0      90       0    1  ...
# 2   495    1   43   69.47793     0     1      0     100       0    1  ...
# 3  1201    3   42   89.15934     0     1      0     100       1    1  ...
# 4   934    0   37  137.46581     0     1      0     100       0    0  ...
#
#    str2  strat  symptom  treat  offtrt  cd40  cd420  cd80  cd820  infected
# 0     1      2        0      1       0   322    469   882    754         1
# 1     1      3        1      1       1   168    575  1035   1525         1
# 2     1      1        0      0       0   377    333  1147   1088         1
# 3     1      3        0      0       0   238    324   775   1019         1
# 4     0      3        0      0       1   500    443  1601    849         0
#
# [5 rows x 23 columns]

# %% [markdown]
# # Exploratory Data analysis - EDA
# #### Explore, study and visualize data

# %%
# Bottom five data values
df.tail()
# Out:
#        time  trt  age      wtkg  hemo  homo  drugs  karnof  oprior  z30  ...  \
# 49995   953    3   46  61.28204     0     0      0      90       0    1  ...
# 49996  1036    0   42  73.36768     0     1      0     100       0    1  ...
# 49997  1157    0   40  78.75824     0     1      0     100       0    1  ...
# 49998   596    0   31  52.20371     0     0      0     100       0    1  ...
# 49999   612    2   41  77.12100     0     1      0      90       0    1  ...
#
#        str2  strat  symptom  treat  offtrt  cd40  cd420  cd80  cd820  infected
# 49995     1      3        0      1       1   234    402   481   1014         0
# 49996     1      3        0      0       1   369    575   514    657         0
# 49997     1      1        0      1       0   308    663  1581    863         0
# 49998     1      1        0      1       1   349    440   470    865         1
# 49999     1      3        0      1       0   428    396  1002    696         0
#
# [5 rows x 23 columns]

# %%
df.shape
# Out:
# (50000, 23)

# %% [markdown]
# The shape of the dataset is 50,000 rows and 23 columns of variables.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 23 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   time      50000 non-null  int64
#  1   trt       50000 non-null  int64
#  2   age       50000 non-null  int64
#  3   wtkg      50000 non-null  float64
#  4   hemo      50000 non-null  int64
#  5   homo      50000 non-null  int64
#  6   drugs     50000 non-null  int64
#  7   karnof    50000 non-null  int64
#  8   oprior    50000 non-null  int64
#  9   z30       50000 non-null  int64
#  10  preanti   50000 non-null  int64
#  11  race      50000 non-null  int64
#  12  gender    50000 non-null  int64
#  13  str2      50000 non-null  int64
#  14  strat     50000 non-null  int64
#  15  symptom   50000 non-null  int64
#  16  treat     50000 non-null  int64
#  17  offtrt    50000 non-null  int64
#  18  cd40      50000 non-null  int64
#  19  cd420     50000 non-null  int64
#  20  cd80      50000 non-null  int64
#  21  cd820     50000 non-null  int64
#  22  infected  50000 non-null  int64
# dtypes: float64(1), int64(22)
# memory usage: 8.8 MB

# %% [markdown]
# We can find the dataset has no null values.
# we can understand the variable datatypes through this.
# No Object type variable is found.

# %%
df.columns.to_list()
# Out:
# ['time',
#  'trt',
#  'age',
#  'wtkg',
#  'hemo',
#  'homo',
#  'drugs',
#  'karnof',
#  'oprior',
#  'z30',
#  'preanti',
#  'race',
#  'gender',
#  'str2',
#  'strat',
#  'symptom',
#  'treat',
#  'offtrt',
#  'cd40',
#  'cd420',
#  'cd80',
#  'cd820',
#  'infected']

# %%
df.describe().T
# Out:
#             count         mean         std        min         25%  \
# time      50000.0   877.369780  307.288688   66.00000  542.000000
# trt       50000.0     1.384800    1.233272    0.00000    0.000000
# age       50000.0    34.164020    7.091152   12.00000   29.000000
# wtkg      50000.0    75.861991   12.028730   42.36162   68.253682
# hemo      50000.0     0.033480    0.179888    0.00000    0.000000
# homo      50000.0     0.653540    0.475847    0.00000    0.000000
# drugs     50000.0     0.132220    0.338733    0.00000    0.000000
# karnof    50000.0    96.831560    5.091788   76.00000   90.000000
# oprior    50000.0     0.042300    0.201275    0.00000    0.000000
# z30       50000.0     0.640880    0.479747    0.00000    0.000000
# preanti   50000.0   318.159560  402.932765    0.00000    0.000000
# race      50000.0     0.293300    0.455279    0.00000    0.000000
# gender    50000.0     0.856700    0.350382    0.00000    1.000000
# str2      50000.0     0.575200    0.494318    0.00000    0.000000
# strat     50000.0     1.936420    0.895318    1.00000    1.000000
# symptom   50000.0     0.083460    0.276579    0.00000    0.000000
# treat     50000.0     0.734160    0.441784    0.00000    0.000000
# offtrt    50000.0     0.342220    0.474458    0.00000    0.000000
# cd40      50000.0   319.079540  102.525976    0.00000  236.000000
# cd420     50000.0   438.090100  144.806831   81.00000  327.000000
# cd80      50000.0  1045.936440  488.617434   96.00000  713.000000
# cd820     50000.0   905.938440  339.707976  173.00000  649.000000
# infected  50000.0     0.310120    0.462547    0.00000    0.000000
#
#                   50%          75%         max
# time      1045.000000  1136.000000  1231.00000
# trt          1.000000     3.000000     3.00000
# age         34.000000    39.000000    68.00000
# wtkg        74.054115    81.142185   149.83087
# hemo         0.000000     0.000000     1.00000
# homo         1.000000     1.000000     1.00000
# drugs        0.000000     0.000000     1.00000
# karnof     100.000000   100.000000   100.00000
# oprior       0.000000     0.000000     1.00000
# z30          1.000000     1.000000     1.00000
# preanti    123.000000   503.000000  2828.00000
# race         0.000000     1.000000     1.00000
# gender       1.000000     1.000000     1.00000
# str2         1.000000     1.000000     1.00000
# strat        2.000000     3.000000     3.00000
# symptom      0.000000     0.000000     1.00000
# treat        1.000000     1.000000     1.00000
# offtrt       0.000000     1.000000     1.00000
# cd40       299.000000   396.000000   930.00000
# cd420      415.000000   531.000000  1119.00000
# cd80       885.000000  1245.000000  4656.00000
# cd820      858.000000  1084.000000  3538.00000
# infected     0.000000     1.000000     1.00000

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.corr().style.background_gradient()
# Out:
# <style type="text/css">
# #T_3736c_row0_col0, #T_3736c_row1_col1, #T_3736c_row2_col2, #T_3736c_row3_col3, #T_3736c_row4_col4, #T_3736c_row5_col5, #T_3736c_row6_col6, #T_3736c_row7_col7, #T_3736c_row8_col8, #T_3736c_row9_col9, #T_3736c_row10_col10, #T_3736c_row11_col11, #T_3736c_row12_col12, #T_3736c_row13_col13, #T_3736c_row14_col14, #T_3736c_row15_col15, #T_3736c_row16_col16, #T_3736c_row17_col17, #T_3736c_row18_col18, #T_3736c_row19_col19, #T_3736c_row20_col20, #T_3736c_row21_col21, #T_3736c_row22_col22 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_3736c_row0_col1, #T_3736c_row2_col16, #T_3736c_row3_col11, #T_3736c_row5_col7, #T_3736c_row7_col0, #T_3736c_row18_col17, #T_3736c_row20_col0 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_3736c_row0_col2, #T_3736c_row4_col0, #T_3736c_row8_col4, #T_3736c_row15_col0, #T_3736c_row17_col4, #T_3736c_row18_col1, #T_3736c_row19_col6, #T_3736c_row20_col2 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_3736c_row0_col3, #T_3736c_row6_col7, #T_3736c_row11_col22, #T_3736c_row17_col22, #T_3736c_row18_col0, #T_3736c_row18_col12, #T_3736c_row21_col7 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_3736c_row0_col4, #T_3736c_row0_col20, #T_3736c_row2_col4, #T_3736c_row2_col17, #T_3736c_row3_col20, #T_3736c_row4_col6, #T_3736c_row5_col8, #T_3736c_row7_col20, #T_3736c_row8_col15, #T_3736c_row10_col18, #T_3736c_row12_col4, #T_3736c_row12_col8, #T_3736c_row12_col20, #T_3736c_row15_col1, #T_3736c_row15_col6, #T_3736c_row17_col12, #T_3736c_row18_col13, #T_3736c_row20_col6, #T_3736c_row20_col8, #T_3736c_row22_col3 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_3736c_row0_col5, #T_3736c_row5_col18, #T_3736c_row6_col9 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_3736c_row0_col6, #T_3736c_row1_col8, #T_3736c_row1_col21, #T_3736c_row3_col8, #T_3736c_row3_col15, #T_3736c_row8_col6, #T_3736c_row10_col3, #T_3736c_row12_col11, #T_3736c_row12_col15, #T_3736c_row15_col21, #T_3736c_row17_col1, #T_3736c_row18_col20, #T_3736c_row18_col22, #T_3736c_row20_col15 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_3736c_row0_col7, #T_3736c_row1_col0, #T_3736c_row3_col9, #T_3736c_row5_col16, #T_3736c_row7_col14, #T_3736c_row9_col5, #T_3736c_row11_col14, #T_3736c_row15_col11, #T_3736c_row18_col3, #T_3736c_row20_col12, #T_3736c_row21_col22 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_3736c_row0_col8, #T_3736c_row4_col20, #T_3736c_row6_col20, #T_3736c_row7_col16, #T_3736c_row9_col18, #T_3736c_row9_col19, #T_3736c_row11_col8, #T_3736c_row12_col21, #T_3736c_row13_col0, #T_3736c_row16_col20, #T_3736c_row17_col20, #T_3736c_row17_col21, #T_3736c_row18_col2 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_3736c_row0_col9, #T_3736c_row6_col10, #T_3736c_row8_col18, #T_3736c_row10_col5, #T_3736c_row16_col12, #T_3736c_row18_col7 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_3736c_row0_col10, #T_3736c_row5_col0, #T_3736c_row7_col5, #T_3736c_row12_col0, #T_3736c_row13_col5, #T_3736c_row19_col5, #T_3736c_row20_col7 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_3736c_row0_col11, #T_3736c_row1_col22, #T_3736c_row7_col10, #T_3736c_row20_col3, #T_3736c_row21_col0 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_3736c_row0_col12, #T_3736c_row3_col14, #T_3736c_row4_col18 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_3736c_row0_col13, #T_3736c_row5_col2, #T_3736c_row14_col2, #T_3736c_row15_col5 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_3736c_row0_col14 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_3736c_row0_col15, #T_3736c_row1_col15, #T_3736c_row2_col21, #T_3736c_row4_col21, #T_3736c_row5_col21, #T_3736c_row9_col6, #T_3736c_row9_col21, #T_3736c_row10_col6, #T_3736c_row10_col21, #T_3736c_row11_col15, #T_3736c_row11_col21, #T_3736c_row12_col17, #T_3736c_row13_col21, #T_3736c_row14_col3, #T_3736c_row14_col21, #T_3736c_row18_col15, #T_3736c_row22_col1, #T_3736c_row22_col16, #T_3736c_row22_col20 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_3736c_row0_col16, #T_3736c_row3_col10, #T_3736c_row6_col22, #T_3736c_row7_col22, #T_3736c_row8_col11, #T_3736c_row12_col22, #T_3736c_row19_col12 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_3736c_row0_col17, #T_3736c_row5_col4, #T_3736c_row5_col6, #T_3736c_row5_col11, #T_3736c_row5_col17, #T_3736c_row9_col3, #T_3736c_row11_col1, #T_3736c_row11_col2, #T_3736c_row11_col5, #T_3736c_row11_col12, #T_3736c_row11_col16, #T_3736c_row11_col20, #T_3736c_row13_col3, #T_3736c_row13_col7, #T_3736c_row14_col18, #T_3736c_row14_col19, #T_3736c_row16_col15, #T_3736c_row17_col0, #T_3736c_row18_col8, #T_3736c_row19_col8, #T_3736c_row19_col9, #T_3736c_row19_col10, #T_3736c_row19_col13, #T_3736c_row19_col14, #T_3736c_row19_col15, #T_3736c_row19_col22, #T_3736c_row22_col0, #T_3736c_row22_col21 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_3736c_row0_col18, #T_3736c_row3_col5, #T_3736c_row5_col19, #T_3736c_row8_col10, #T_3736c_row16_col9 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_3736c_row0_col19 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_3736c_row0_col21, #T_3736c_row1_col6, #T_3736c_row7_col8, #T_3736c_row7_col15, #T_3736c_row10_col0, #T_3736c_row10_col7, #T_3736c_row14_col11, #T_3736c_row15_col16, #T_3736c_row16_col6, #T_3736c_row16_col21, #T_3736c_row17_col16, #T_3736c_row18_col10, #T_3736c_row19_col21 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_3736c_row0_col22, #T_3736c_row1_col17, #T_3736c_row13_col15, #T_3736c_row17_col3, #T_3736c_row18_col16, #T_3736c_row21_col2, #T_3736c_row22_col17 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_3736c_row1_col2, #T_3736c_row3_col22, #T_3736c_row4_col12, #T_3736c_row6_col5, #T_3736c_row14_col8, #T_3736c_row14_col12, #T_3736c_row16_col2, #T_3736c_row16_col22, #T_3736c_row19_col16 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_3736c_row1_col3, #T_3736c_row2_col0, #T_3736c_row2_col1, #T_3736c_row2_col3, #T_3736c_row4_col17, #T_3736c_row7_col3, #T_3736c_row9_col12, #T_3736c_row10_col4, #T_3736c_row12_col1, #T_3736c_row12_col2, #T_3736c_row13_col8, #T_3736c_row15_col3, #T_3736c_row17_col7, #T_3736c_row22_col12, #T_3736c_row22_col19 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_3736c_row1_col4, #T_3736c_row3_col17, #T_3736c_row4_col1, #T_3736c_row4_col3, #T_3736c_row6_col4, #T_3736c_row10_col1, #T_3736c_row13_col1, #T_3736c_row14_col1, #T_3736c_row16_col17, #T_3736c_row17_col5, #T_3736c_row20_col16, #T_3736c_row21_col20 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_3736c_row1_col5, #T_3736c_row1_col18, #T_3736c_row8_col19, #T_3736c_row15_col10, #T_3736c_row20_col9 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_3736c_row1_col7, #T_3736c_row2_col11, #T_3736c_row8_col17, #T_3736c_row9_col17, #T_3736c_row10_col8, #T_3736c_row10_col17, #T_3736c_row14_col16, #T_3736c_row16_col11, #T_3736c_row17_col6, #T_3736c_row19_col1, #T_3736c_row20_col17, #T_3736c_row22_col4, #T_3736c_row22_col8, #T_3736c_row22_col18 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_3736c_row1_col9, #T_3736c_row17_col14, #T_3736c_row21_col9 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_3736c_row1_col10, #T_3736c_row2_col19, #T_3736c_row12_col10, #T_3736c_row21_col10 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_3736c_row1_col11, #T_3736c_row6_col12, #T_3736c_row9_col8, #T_3736c_row11_col6, #T_3736c_row13_col12, #T_3736c_row13_col17, #T_3736c_row15_col17, #T_3736c_row16_col3, #T_3736c_row21_col17, #T_3736c_row22_col2, #T_3736c_row22_col7 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_3736c_row1_col12, #T_3736c_row16_col0 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_3736c_row1_col13, #T_3736c_row3_col18, #T_3736c_row7_col18, #T_3736c_row17_col13, #T_3736c_row21_col13 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_3736c_row1_col14, #T_3736c_row15_col9 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_3736c_row1_col16, #T_3736c_row3_col19, #T_3736c_row4_col14, #T_3736c_row7_col19 {
#   background-color: #c4cbe3;
#   colo

# %% [markdown]
# # Data visualization

# %%
sns.countplot(df,x='gender',hue='infected')
plt.xlabel("Gender & their status")
plt.ylabel("Count")
plt.show()

# %%
# Calculate total number of people by gender
total_by_gender = df['gender'].value_counts()

# Calculate number of infected people by gender
infected_by_gender = df[df['infected'] == True]['gender'].value_counts()

# Calculate percentage of infected people by gender
percentage_infected_by_gender = (infected_by_gender / total_by_gender) * 100

print(percentage_infected_by_gender)
# Out:
# gender
# 1    30.594140
# 0    33.510119
# Name: count, dtype: float64

# %% [markdown]
# Gender based infection distribution is 30% - Male & 33% - Female

# %%
ax =sns.countplot(df,x='infected')
total = df['infected'].count()
ax.bar_label(ax.containers[0], fmt=lambda x: f'{(x/total)*100:.1f}%')
plt.title('Percentage of patients and their status')
plt.xlabel("Infection status")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# We could see that dataset is imbalanced. Infected column consists of categorical of 0 & 1.
# '0' is 69% registered and '1' is 31% registered.

# %%
# Box plot
plt.figure(figsize=(20,5))
sns.boxplot(df)
plt.show()

# %% [markdown]
# ## Model preparation

# %%
# Before sampling
X = df.drop(['infected'], axis='columns')
y = df['infected']
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=5)

# %%
# Importing standard scler and Scaling the data

ss = StandardScaler()
X_train.iloc[:,:] = ss.fit_transform(X_train.iloc[:,:])
X_test.iloc[:,:] = ss.transform(X_test.iloc[:,:])

# %%
lr = LogisticRegression()
log_reg = lr.fit(X_train,y_train)

# %%
y_train_pred = log_reg.predict(X_train)

# %%
log_reg.coef_
# Out:
# array([[-0.15869112, -0.07047829, -0.02918593, -0.04290289,  0.00148042,
#          0.01228369, -0.04404677,  0.02519291,  0.04152064,  0.23937162,
#          0.03263123,  0.01731776, -0.02547234,  0.16409076,  0.22877107,
#          0.03799317, -0.1003321 , -0.08013588, -0.15019194, -0.21352946,
#         -0.0044625 , -0.02990675]])

# %%
log_reg.intercept_
# Out:
# array([-0.90986136])

# %%
# Model score 

model_score = lr.score(X_train,y_train)
model_score
# Out:
# 0.7072285714285714

# %%
# Y train probability
y_train_prob = lr.predict_proba(X_train)

# Y train predict 
y_train_pred = lr.predict(X_train)

# Y test probability
y_test_prob = lr.predict_proba(X_test)

# Y test predict
y_test_pred = lr.predict(X_test)

# %% [markdown]
# #  Confusion Matrix

# %%
# Accuracy score for test data
metrics.accuracy_score(y_test,y_test_pred)
# Out:
# 0.7077333333333333

# %%
cm = confusion_matrix(y_test,y_test_pred)

dip = ConfusionMatrixDisplay(confusion_matrix=cm)
dip.plot()
plt.show()

# %%
from sklearn.ensemble import BalancedRandomForestClassifier

# Create a BalancedRandomForest classifier
clf = BalancedRandomForestClassifier(random_state=42)

# Train the classifier
clf.fit(X_train, y_train)

# Predict on the test set
y_pred = clf.predict(X_test)

# Evaluate the classifier
print(classification_report(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 from sklearn.ensemble import BalancedRandomForestClassifier
#       3 # Create a BalancedRandomForest classifier
#       4 clf = BalancedRandomForestClassifier(random_state=42)
#
# ImportError: cannot import name 'BalancedRandomForestClassifier' from 'sklearn.ensemble' (c:\ProgramData\anaconda3\anaconda4\Lib\site-packages\sklearn\ensemble\__init__.py)
